# %%
2 + 2
# Out:
# 4

# %%
4 * 2
# Out:
# 8

# %%
4 ** 2
# Out:
# 16

# %%
4 * * 2
# Out:
#   Cell In[4], line 1
#     4 * * 2
#         ^
# SyntaxError: invalid syntax

# %%
# this is a comment--it's just a note for the programmer
# it's not code
2 + 2  # adds 2 and 2
# Out:
# 4

# %%
pi = 3.1415927

# %%
pi
# Out:
# 3.1415927

# %%
pi * (5 ** 2)
# Out:
# 78.5398175

# %%
x = 5

# %%
x
# Out:
# 5

# %%
x * 2
# Out:
# 10

# %%
x = 42  # overwrites the value of x!
y = 43
x + y
# Out:
# 85

# %%
x = x + 1  # RHS gets evaluated and put into LHS
x
# Out:
# 43

# %%
subtotal = 9.99
tax = subtotal * 0.0875
subtotal + tax
# Out:
# 10.864125

# %% [markdown]
# # Function calls

# %%
# ^ this is called Markdown. It's a "programming language" to make pretty documents!

# %%
max(2, 3)
# Out:
# 3

# %%
round(subtotal + tax, 2)
# Out:
# 10.86

# %%
abs(-42)
# Out:
# 42

# %% [markdown]
# # Libraries

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
math.log?
# Out:
# Docstring:
# log(x, [base=math.e])
# Return the logarithm of x to the given base.
#
# If the base is not specified, returns the natural logarithm (base e) of x.
# Type:      builtin_function_or_method

# %%
math.log(32, 2)
# Out:
# 5.0

# %%
from math import sqrt
sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # Tables

# %%
from datascience import *
# the * imports everything into the "top level" so I don't have to say datascience.______

# %%
Table.read_table?
# Out:
# Signature: Table.read_table(filepath_or_buffer, *args, **vargs)
# Docstring:
# Read a table from a file or web address.
#
# Args:
#     filepath_or_buffer -- string or file handle / StringIO; The string
#                       could be a URL. Valid URL schemes include http,
#                       ftp, s3, and file.
#
# Returns:
#     a table read from argument
#
# Example:
#
# >>> Table.read_table('https://www.inferentialthinking.com/data/sat2014.csv')
# State        | Participation Rate | Critical Reading | Math | Writing | Combined
# North Dakota | 2.3                | 612              | 620  | 584     | 1816
# Illinois     | 4.6                | 599              | 616  | 587     | 1802
# Iowa         | 3.1                | 605              | 611  | 578     | 1794
# South Dakota | 2.9                | 604              | 609  | 579     | 1792
# Minnesota    | 5.9                | 598              | 610  | 578     | 1786
# ...

# %%
cones = Table.read_table('data/cones.csv')
cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# vanilla    | white       | 3.5
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
cones.show(2)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Color</th> <th>Price</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>3.55 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>light brown</td> <td>4.75 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (5 rows omitted)</p>

# %%
cones.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Color</th> <th>Price</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>3.55 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>light brown</td> <td>4.75 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>vanilla   </td> <td>white      </td> <td>3.5  </td>
#         </tr>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>bubblegum </td> <td>pink       </td> <td>4.75 </td>
#         </tr>
#     </tbody>
# </table>

# %%
cones.select('Flavor')
# Out:
# Flavor
# strawberry
# chocolate
# chocolate
# vanilla
# strawberry
# chocolate
# bubblegum

# %%
cones  # hasn't changed
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# vanilla    | white       | 3.5
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
cones.select('Flavor', 'Color')
# Out:
# Flavor     | Color
# strawberry | pink
# chocolate  | light brown
# chocolate  | dark brown
# vanilla    | white
# strawberry | pink
# chocolate  | dark brown
# bubblegum  | pink

# %%
cones_no_price = cones.drop('Price')
cones_no_price
# Out:
# Flavor     | Color
# strawberry | pink
# chocolate  | light brown
# chocolate  | dark brown
# vanilla    | white
# strawberry | pink
# chocolate  | dark brown
# bubblegum  | pink

# %%
cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# vanilla    | white       | 3.5
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
cones.sort('Price')
# Out:
# Flavor     | Color       | Price
# vanilla    | white       | 3.5
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# bubblegum  | pink        | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25

# %%
cones.sort('Price', descending=True)
# Out:
# Flavor     | Color       | Price
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# chocolate  | light brown | 4.75
# bubblegum  | pink        | 4.75
# strawberry | pink        | 3.55
# vanilla    | white       | 3.5

# %%
cones.where('Flavor', 'chocolate')
# Out:
# Flavor    | Color       | Price
# chocolate | light brown | 4.75
# chocolate | dark brown  | 5.25
# chocolate | dark brown  | 5.25

# %%
pokemon = Table.read_table('data/pokemon.csv')
pokemon
# Out:
# abilities                   | against_bug | against_dark | against_dragon | against_electric | against_fairy | against_fight | against_fire | against_flying | against_ghost | against_grass | against_ground | against_ice | against_normal | against_poison | against_psychic | against_rock | against_steel | against_water | attack | base_egg_steps | base_happiness | base_total | capture_rate | classfication       | defense | experience_growth | height_m | hp   | japanese_name    | name       | percentage_male | pokedex_number | sp_attack | sp_defense | speed | type1 | type2  | weight_kg | generation | is_legendary
# ...

# %%
pokemon.where('name', 'Pikachu')
# Out:
# abilities                  | against_bug | against_dark | against_dragon | against_electric | against_fairy | against_fight | against_fire | against_flying | against_ghost | against_grass | against_ground | against_ice | against_normal | against_poison | against_psychic | against_rock | against_steel | against_water | attack | base_egg_steps | base_happiness | base_total | capture_rate | classfication | defense | experience_growth | height_m | hp   | japanese_name | name    | percentage_male | pokedex_number | sp_attack | sp_defense | speed | type1    | type2 | weight_kg | generation | is_legendary
# ...

# %%
pokemon.where('type1', 'electric')
# Out:
# abilities                                  | against_bug | against_dark | against_dragon | against_electric | against_fairy | against_fight | against_fire | against_flying | against_ghost | against_grass | against_ground | against_ice | against_normal | against_poison | against_psychic | against_rock | against_steel | against_water | attack | base_egg_steps | base_happiness | base_total | capture_rate | classfication      | defense | experience_growth | height_m | hp   | japanese_name   | name       | percentage_male | pokedex_number | sp_attack | sp_defense | speed | type1    | type2    | weight_kg | generation | is_legendary
# ...

# %%
gen1 = pokemon.where('generation', 1)

# %%
gen1.sort('attack', descending=True)
# Out:
# abilities                                      | against_bug | against_dark | against_dragon | against_electric | against_fairy | against_fight | against_fire | against_flying | against_ghost | against_grass | against_ground | against_ice | against_normal | against_poison | against_psychic | against_rock | against_steel | against_water | attack | base_egg_steps | base_happiness | base_total | capture_rate | classfication      | defense | experience_growth | height_m | hp   | japanese_name | name       | percentage_male | pokedex_number | sp_attack | sp_defense | speed | type1    | type2  | weight_kg | generation | is_legendary
# ...

# %%
gen1.sort('attack', descending=True).select('name', 'type1', 'attack')
# Out:
# name       | type1    | attack
# Pinsir     | bug      | 155
# Gyarados   | water    | 155
# Beedrill   | bug      | 150
# Mewtwo     | psychic  | 150
# Aerodactyl | rock     | 135
# Dragonite  | dragon   | 134
# Machamp    | fighting | 130
# Kingler    | water    | 130
# Rhydon     | ground   | 130
# Flareon    | fire     | 130
# ... (141 rows omitted)

# %%
# question: find the top 8 generation 2 pokemon with the highest defense
pokemon.sort('defense', descending=True).where('generation', 2).select('name', 'defense').show(8)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>defense</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Steelix   </td> <td>230    </td>
#         </tr>
#         <tr>
#             <td>Shuckle   </td> <td>230    </td>
#         </tr>
#         <tr>
#             <td>Tyranitar </td> <td>150    </td>
#         </tr>
#         <tr>
#             <td>Forretress</td> <td>140    </td>
#         </tr>
#         <tr>
#             <td>Scizor    </td> <td>140    </td>
#         </tr>
#         <tr>
#             <td>Skarmory  </td> <td>140    </td>
#         </tr>
#         <tr>
#             <td>Lugia     </td> <td>130    </td>
#         </tr>
#         <tr>
#             <td>Magcargo  </td> <td>120    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (92 rows omitted)</p>

# %% [markdown]
# # Miscellaneous things Lawton needs to teach you today

# %%
print("hi mom!")
# Out:
# hi mom!

# %%
"hi mom!"
# Out:
# 'hi mom!'

# %%
print('hi mom!')
print("we'll also see this in the output")
# Out:
# hi mom!
# we'll also see this in the output

# %%
print(42, 43, 44)
# Out:
# 42 43 44

# %%
x = 42
print(x * 2)
x * 7 + 11
# Out:
# 84
# 305
